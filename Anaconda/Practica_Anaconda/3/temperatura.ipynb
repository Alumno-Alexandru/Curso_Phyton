# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (2.3.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
# Installing collected packages: tensorflow
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\Users\\Alex\\Documents\\GS_Daw\\PCP_programacion_phyton\\Curso_Phyton\\envINICIAL\\Lib\\site-packages\\tensorflow\\include\\external\\envoy_api\\envoy\\extensions\\load_balancing_policies\\client_side_weighted_round_robin\\v3\\client_side_weighted_round_robin.upb_minitable.h'
#
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import tensorflow as tf
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\alex\documents\gs_daw\pcp_programacion_phyton\curso_phyton\envinicial\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Using cached tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
# Installing collected packages: tensorflow
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\Users\\Alex\\Documents\\GS_Daw\\PCP_programacion_phyton\\Curso_Phyton\\envINICIAL\\Lib\\site-packages\\tensorflow\\include\\external\\envoy_api\\envoy\\extensions\\load_balancing_policies\\client_side_weighted_round_robin\\v3\\client_side_weighted_round_robin.upb_minitable.h'
#
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 get_ipython().run_line_magic('pip', 'install tensorflow')
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#
# File c:\Users\Alex\Documents\GS_Daw\PCP_programacion_phyton\Curso_Phyton\envINICIAL\Lib\site-packages\tensorflow\__init__.py:40
#      37 _os.environ.setdefault("ENABLE_RUNTIME_UPTIME_TELEMETRY", "1")
#      39 # Do not remove this line; See https://github.com/tensorflow/tensorflow/issues/42596
# ---> 40 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow  # pylint: disable=unused-import
#      41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import KerasLazyLoader as _KerasLazyLoader
#
# ModuleNotFoundError: No module named 'tensorflow.python'

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=!, input_shape=[1])
modelo = tf.keras.Sequential([capa])
# Out:
#   Cell In[1], line 1
#     capa = tf.keras.layers.Dense(units=!, input_shape=[1])
#                                        ^
# SyntaxError: invalid syntax

# %%
modelo.compile (
    optimizer = tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print('Comenzando entrenamiento...')
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print('Modelo entrenado')

# %%
import matplotlib.pylot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
print("Hagamos una prediccion")
resultado= modelo.predict([100.0])
print("El resultado es " + str(resultado) + "fahrenheit")
