# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: numpy in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# Requirement already satisfied: tensorflow in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (12.6.0)
# Requirement already satisfied: namex in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import tensorflow as tf
# Out:
# 2026-01-14 15:11:50.828278: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-01-14 15:11:50.895945: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-14 15:11:53.290616: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])
# Out:
# /home/1987b19f-2ad9-4fe9-b988-5051a7b1ab4c/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-01-14 15:11:54.912359: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
modelo.compile (
    optimizer = tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print('Comenzando entrenamiento...')
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print('Modelo entrenado')
# Out:
# Comenzando entrenamiento...
# Modelo entrenado

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
print("Hagamos una predicción")
resultado = modelo.predict(np.array([[100.0]]))
print("El resultado es", resultado[0][0], "fahrenheit")
# Out:
# Hagamos una predicción
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# El resultado es 211.7427 fahrenheit
